# %% [markdown]
# # Data scraping using the Selenium Webdriver

# %% [markdown]
# In this notebook, we use `pandas`, `requests`, and `selenium.webdriver` libraries to extract data tables with information about Tokyo 2020 Paralympic Games from the official [website](https://olympics.com/tokyo-2020/en/paralympics/) of the games. Note that for this notebook to work properly, the selenium webdriver for chrome needs to downloaded from the official [website](https://chromedriver.chromium.org/), installed, and the folder with the corresponding executable file needs be be added to your path (alternatively, one needs to always specify the when running the webdriver: `webdriver.Chrome(/path/to/chromedriver)`).

# %% [markdown]
# ### Extract Medals data using Pandas and Requests

# %%
import requests
import pandas as pd

url = 'https://olympics.com/tokyo-2020/paralympic-games/en/results/all-sports/medal-standings.htm'
html = requests.get(url).content
medals_list = pd.read_html(html)

# %%
#0's entry in medals_list contains the overall medal summary table
medals = medals_list[0]
medals.head()
# Out:
#    Rank                    Team/NPC  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0     1  People's Republic of China          96          60          51
# 1     2               Great Britain          41          38          45
# 2     3    United States of America          37          36          31
# 3     4                         RPC          36          33          49
# 4     5                 Netherlands          25          17          17
#
#    Total  RankbyTotal NPCCode
# 0    207            1     CHN
# 1    124            2     GBR
# 2    104            4     USA
# 3    118            3     RPC
# 4     59            9     NED

# %%
#Rename columns properly
medals.rename(columns={'Unnamed: 2' : 'Gold', 'Unnamed: 3' : 'Silver', 
                       'Unnamed: 4': 'Bronze', 'RankbyTotal': 'Rank by Total'}, 
              inplace=True)

#Drop the 'NPCCode' column
medals.drop(columns=['NPCCode'], inplace=True)

#Take a look at the modified table
medals.head()
# Out:
#    Rank                    Team/NPC  Gold  Silver  Bronze  Total  \
# 0     1  People's Republic of China    96      60      51    207
# 1     2               Great Britain    41      38      45    124
# 2     3    United States of America    37      36      31    104
# 3     4                         RPC    36      33      49    118
# 4     5                 Netherlands    25      17      17     59
#
#    Rank by Total
# 0              1
# 1              2
# 2              4
# 3              3
# 4              9

# %%
#Export data to a cvs file
medals.to_csv('Medals.csv', index=False)

# %% [markdown]
# ### Extract Athletes data using Selenium

# %%
import time
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC

driver = webdriver.Chrome()
url = 'https://olympics.com/tokyo-2020/paralympic-games/en/results/all-sports/medal-standings.htm'
driver.get(url)
time.sleep(2)

#Cookies
not_accept_xpath = '//*[@id="onetrust-pc-btn-handler"]'
not_accept = driver.find_element_by_xpath(not_accept_xpath)
not_accept.click()
time.sleep(2)

cookies_xpath = '//*[@id="onetrust-pc-sdk"]/div[3]/div[1]/button[1]'
cookies = driver.find_element_by_xpath(cookies_xpath)
cookies.click()
time.sleep(3)

#Athletes tab
athletes_button_xp = '/html/body/section[2]/div/header/div[2]/div[1]/div/div[2]/nav/ul[1]/li[6]/a'
athletes_button = driver.find_element_by_xpath(athletes_button_xp)
athletes_button.click()
time.sleep(3)

#Extract html of the athletes table 
athletes_table_xp = '//*[@id="entries-table"]'
athletes_table = driver.find_element_by_xpath(athletes_table_xp)
athletes_html_full = athletes_table.get_attribute('outerHTML')

#Remove undesireble text patterns in the table
remove_pattern_1 = r';[^>]+;'
remove_pattern_2 = r'<span class="d-md-none">[^>]+</span>'
remove_pattern = r'|'.join((remove_pattern_1, remove_pattern_2))
athletes_html_clean = re.sub(remove_pattern, '', athletes_html_full)

#Record 1st page data
athletes_p1_list = pd.read_html(athletes_html_clean)
athletes_p1 = athletes_p1_list[0]
athletes_p1.index = athletes_p1.index + 1 + 20*0
athletes_list = [athletes_p1]
time.sleep(2)

#Record pages 2-227
for i in range(2, 228):
    j = i
    if i > 5:
        j = 5
    if i == 226:
        j = 6
    if i == 227:
        j = 7    
    next_page_xpath = f'//*[@id="entries-table_paginate"]/ul/li[{j+1}]/a'
    next_page = driver.find_element_by_xpath(next_page_xpath)
    next_page.click()
    
    athletes_html_full = athletes_table.get_attribute('outerHTML')
    athletes_html_clean = re.sub(remove_pattern, '', athletes_html_full)
    
    athletes_nextp_list = pd.read_html(athletes_html_clean)
    athletes_nextp = athletes_nextp_list[0]
    athletes_nextp.index = athletes_nextp.index + 1 + 20*(i-1)
    athletes_list.append(athletes_nextp)
    time.sleep(2)

athletes_final = pd.concat(athletes_list)

# %%
#Check out the resulting table
athletes_final.head()
# Out:
#                Name         NPC             Discipline
# 1    AAJIM Munkhbat    Mongolia                   Judo
# 2    ABARZA Alberto       Chile               Swimming
# 3      ABASLI Namig  Azerbaijan                   Judo
# 4    ABASSI Mostefa     Algeria  Wheelchair Basketball
# 5  ABBAD Abderraouf     Algeria  Wheelchair Basketball

# %%
#Export data to a cvs file
athletes_final.to_csv('Athletes.csv', index=False)

# %% [markdown]
# ### Extract Gender by Discipline data using pandas

# %%
import requests
import pandas as pd

url = 'https://olympics.com/tokyo-2020/paralympic-games/en/results/all-sports/entries-by-discipline.htm'
html = requests.get(url).content
gender_list = pd.read_html(html)

# %%
#0's entry in the medals_list contains the overall medal table
gender = gender_list[0]
gender.tail()
# Out:
#                Discipline Gender
#                Discipline      F     M Total
# 19  Wheelchair Basketball    118   144   262
# 20     Wheelchair Fencing     48    48    96
# 21       Wheelchair Rugby      4    88    92
# 22      Wheelchair Tennis     32    72   104
# 23                  Total   1895  2632  4527

# %%
#Remove redundant multiindexing in column titles
gender.columns = ['Discipline', 'F', 'M', 'Total']

#Remove the last row
gender = gender[:-1]

#Display data
gender.style.set_properties(**{'text-align': 'right'})
# Out:
# <style  type="text/css" >
# #T_6c765_row0_col0,#T_6c765_row0_col1,#T_6c765_row0_col2,#T_6c765_row0_col3,#T_6c765_row1_col0,#T_6c765_row1_col1,#T_6c765_row1_col2,#T_6c765_row1_col3,#T_6c765_row2_col0,#T_6c765_row2_col1,#T_6c765_row2_col2,#T_6c765_row2_col3,#T_6c765_row3_col0,#T_6c765_row3_col1,#T_6c765_row3_col2,#T_6c765_row3_col3,#T_6c765_row4_col0,#T_6c765_row4_col1,#T_6c765_row4_col2,#T_6c765_row4_col3,#T_6c765_row5_col0,#T_6c765_row5_col1,#T_6c765_row5_col2,#T_6c765_row5_col3,#T_6c765_row6_col0,#T_6c765_row6_col1,#T_6c765_row6_col2,#T_6c765_row6_col3,#T_6c765_row7_col0,#T_6c765_row7_col1,#T_6c765_row7_col2,#T_6c765_row7_col3,#T_6c765_row8_col0,#T_6c765_row8_col1,#T_6c765_row8_col2,#T_6c765_row8_col3,#T_6c765_row9_col0,#T_6c765_row9_col1,#T_6c765_row9_col2,#T_6c765_row9_col3,#T_6c765_row10_col0,#T_6c765_row10_col1,#T_6c765_row10_col2,#T_6c765_row10_col3,#T_6c765_row11_col0,#T_6c765_row11_col1,#T_6c765_row11_col2,#T_6c765_row11_col3,#T_6c765_row12_col0,#T_6c765_row12_col1,#T_6c765_row12_col2,#T_6c765_row12_col3,#T_6c765_row13_col0,#T_6c765_row13_col1,#T_6c765_row13_col2,#T_6c765_row13_col3,#T_6c765_row14_col0,#T_6c765_row14_col1,#T_6c765_row14_col2,#T_6c765_row14_col3,#T_6c765_row15_col0,#T_6c765_row15_col1,#T_6c765_row15_col2,#T_6c765_row15_col3,#T_6c765_row16_col0,#T_6c765_row16_col1,#T_6c765_row16_col2,#T_6c765_row16_col3,#T_6c765_row17_col0,#T_6c765_row17_col1,#T_6c765_row17_col2,#T_6c765_row17_col3,#T_6c765_row18_col0,#T_6c765_row18_col1,#T_6c765_row18_col2,#T_6c765_row18_col3,#T_6c765_row19_col0,#T_6c765_row19_col1,#T_6c765_row19_col2,#T_6c765_row19_col3,#T_6c765_row20_col0,#T_6c765_row20_col1,#T_6c765_row20_col2,#T_6c765_row20_col3,#T_6c765_row21_col0,#T_6c765_row21_col1,#T_6c765_row21_col2,#T_6c765_row21_col3,#T_6c765_row22_col0,#T_6c765_row22_col1,#T_6c765_row22_col2,#T_6c765_row22_col3{
#             text-align:  right;
#         }</style><table id="T_6c765_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Discipline</th>        <th class="col_heading level0 col1" >F</th>        <th class="col_heading level0 col2" >M</th>        <th class="col_heading level0 col3" >Total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6c765_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6c765_row0_col0" class="data row0 col0" >Archery</td>
#                         <td id="T_6c765_row0_col1" class="data row0 col1" >60</td>
#                         <td id="T_6c765_row0_col2" class="data row0 col2" >79</td>
#                         <td id="T_6c765_row0_col3" class="data row0 col3" >139</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6c765_row1_col0" class="data row1 col0" >Athletics</td>
#                         <td id="T_6c765_row1_col1" class="data row1 col1" >489</td>
#                         <td id="T_6c765_row1_col2" class="data row1 col2" >653</td>
#                         <td id="T_6c765_row1_col3" class="data row1 col3" >1142</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6c765_row2_col0" class="data row2 col0" >Badminton</td>
#                         <td id="T_6c765_row2_col1" class="data row2 col1" >44</td>
#                         <td id="T_6c765_row2_col2" class="data row2 col2" >46</td>
#                         <td id="T_6c765_row2_col3" class="data row2 col3" >90</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6c765_row3_col0" class="data row3 col0" >Boccia</td>
#                         <td id="T_6c765_row3_col1" class="data row3 col1" >41</td>
#                         <td id="T_6c765_row3_col2" class="data row3 col2" >73</td>
#                         <td id="T_6c765_row3_col3" class="data row3 col3" >114</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6c765_row4_col0" class="data row4 col0" >Canoe Sprint</td>
#                         <td id="T_6c765_row4_col1" class="data row4 col1" >40</td>
#                         <td id="T_6c765_row4_col2" class="data row4 col2" >51</td>
#                         <td id="T_6c765_row4_col3" class="data row4 col3" >91</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6c765_row5_col0" class="data row5 col0" >Cycling Road</td>
#                         <td id="T_6c765_row5_col1" class="data row5 col1" >74</td>
#                         <td id="T_6c765_row5_col2" class="data row5 col2" >139</td>
#                         <td id="T_6c765_row5_col3" class="data row5 col3" >213</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6c765_row6_col0" class="data row6 col0" >Cycling Track</td>
#                         <td id="T_6c765_row6_col1" class="data row6 col1" >43</td>
#                         <td id="T_6c765_row6_col2" class="data row6 col2" >72</td>
#                         <td id="T_6c765_row6_col3" class="data row6 col3" >115</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6c765_row7_col0" class="data row7 col0" >Equestrian</td>
#                         <td id="T_6c765_row7_col1" class="data row7 col1" >55</td>
#                         <td id="T_6c765_row7_col2" class="data row7 col2" >22</td>
#                         <td id="T_6c765_row7_col3" class="data row7 col3" >77</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_6c765_row8_col0" class="data row8 col0" >Football 5-a-side</td>
#                         <td id="T_6c765_row8_col1" class="data row8 col1" >0</td>
#                         <td id="T_6c765_row8_col2" class="data row8 col2" >78</td>
#                         <td id="T_6c765_row8_col3" class="data row8 col3" >78</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_6c765_row9_col0" class="data row9 col0" >Goalball</td>
#                         <td id="T_6c765_row9_col1" class="data row9 col1" >58</td>
#                         <td id="T_6c765_row9_col2" class="data row9 col2" >60</td>
#                         <td id="T_6c765_row9_col3" class="data row9 col3" >118</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_6c765_row10_col0" class="data row10 col0" >Judo</td>
#                         <td id="T_6c765_row10_col1" class="data row10 col1" >56</td>
#                         <td id="T_6c765_row10_col2" class="data row10 col2" >80</td>
#                         <td id="T_6c765_row10_col3" class="data row10 col3" >136</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_6c765_row11_col0" class="data row11 col0" >Powerlifting</td>
#                         <td id="T_6c765_row11_col1" class="data row11 col1" >88</td>
#                         <td id="T_6c765_row11_col2" class="data row11 col2" >90</td>
#                         <td id="T_6c765_row11_col3" class="data row11 col3" >178</td>
#             </tr>
#             <tr>
#                         <th id="T_6c765_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_6c765_r

# %%
#Export data to a cvs file
gender.to_csv('GenderByDiscipline.csv', index=False)

# %% [markdown]
# ### Extract Coaches data using Selenium

# %%
import re
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()
url = 'https://olympics.com/tokyo-2020/paralympic-games/en/results/all-sports/coaches.htm'
driver.get(url)
time.sleep(2)

#Cookies
not_accept_xpath = '//*[@id="onetrust-pc-btn-handler"]'
not_accept = driver.find_element_by_xpath(not_accept_xpath)
not_accept.click()
time.sleep(2)

cookies_xpath = '//*[@id="onetrust-pc-sdk"]/div[3]/div[1]/button[1]'
cookies = driver.find_element_by_xpath(cookies_xpath)
cookies.click()
time.sleep(3)

#Extract html of the coaches table 
coaches_table_xp = '//*[@id="mainContainer"]/div/div[1]/div[1]/div[3]'
coaches_table = driver.find_element_by_xpath(coaches_table_xp)
coaches_html_full = coaches_table.get_attribute('outerHTML')

#Remove undesireble text patterns in the table
remove_pattern_1 = r';[^>]+;'
remove_pattern_2 = r'<span class="d-md-none">[^>]+</span>'
remove_pattern = r'|'.join((remove_pattern_1, remove_pattern_2))
coaches_html_clean = re.sub(remove_pattern, '', coaches_html_full)

#Record 1st page data
coaches_p1_list = pd.read_html(coaches_html_clean)
coaches_p1 = coaches_p1_list[0]
coaches_p1.index = coaches_p1.index + 1 + 20*0
coaches_list = [coaches_p1]
time.sleep(2)

#Record pages 2-5
for i in range(2, 6):        
    next_page_xpath = f'//*[@id="entries-table_paginate"]/ul/li[{i+1}]/a'
    next_page = driver.find_element_by_xpath(next_page_xpath)
    next_page.click()
    
    coaches_html_full = coaches_table.get_attribute('outerHTML')
    coaches_html_clean = re.sub(remove_pattern, '', coaches_html_full)
    
    coaches_nextp_list = pd.read_html(coaches_html_clean)
    coaches_nextp = coaches_nextp_list[0]
    coaches_nextp.index = coaches_nextp.index + 1 + 20*(i-1)
    coaches_list.append(coaches_nextp)
    time.sleep(2)

coaches_final = pd.concat(coaches_list)
coaches_final.rename(columns={'Event': 'Gender'}, inplace=True)

# %%
coaches_final
# Out:
#                   Name                         NPC             Discipline  \
# 1   AGHAKOUCHEKI Abbas    Islamic Republic of Iran  Wheelchair Basketball
# 2           AKIN Ahmet                      Turkey  Wheelchair Basketball
# 3     AKPWEH Toussaint                      France      Football 5-a-side
# 4         ARIMA Masato                       Japan  Wheelchair Basketball
# 5           BAN Nicole                      Canada     Sitting Volleyball
# ..                 ...                         ...                    ...
# 87            XU Yufei  People's Republic of China      Football 5-a-side
# 88             YE Jing  People's Republic of China     Sitting Volleyball
# 89        YIN Shiqiang  People's Republic of China               Goalball
# 90         YOUNG Keith    United States of America               Goalball
# 91   ZELTINGER Nicolai                     Germany  Wheelchair Basketball
#
#    Gender
# 1     Men
# 2     Men
# 3     Men
# 4     NaN
# 5   Women
# ..    ...
# 87    Men
# 88    Men
# 89    Men
# 90    Men
# 91    Men
#
# [91 rows x 4 columns]

# %%
#Export data to a cvs file
coaches_final.to_csv('Coaches.csv', index=False)

# %% [markdown]
# ### Extract Medalists data using Padnas and Requests

# %%
import re
import time
import requests
import pandas as pd
url = 'https://olympics.com/tokyo-2020/paralympic-games/en/results/all-sports/multi-medalists.htm'

mmedallists_html_full = requests.get(url).content
mmedallists = pd.read_html(mmedallists_html_full)
mmedallists[0]
# Out:
#      Rank                                             Name     Sport  \
# 0       1   UKRKRYPAK MKRYPAK Maksym Sport Class: S10,SM10  Swimming
# 1       1   UKRKRYPAK MKRYPAK Maksym Sport Class: S10,SM10  Swimming
# 2       1   UKRKRYPAK MKRYPAK Maksym Sport Class: S10,SM10  Swimming
# 3       1   UKRKRYPAK MKRYPAK Maksym Sport Class: S10,SM10  Swimming
# 4       1   UKRKRYPAK MKRYPAK Maksym Sport Class: S10,SM10  Swimming
# ..    ...                                              ...       ...
# 931   350                CHNWU CWU Chunyan Sport Class: W2   Archery
# 932   350   CHNYANG BYANG Bozun Sport Class: S11,SB11,SM11  Swimming
# 933   350   CHNYANG BYANG Bozun Sport Class: S11,SB11,SM11  Swimming
# 934   350  CHNYANG GYANG Guanglong Sport Class: S8,SB8,SM8  Swimming
# 935   350  CHNYANG GYANG Guanglong Sport Class: S8,SB8,SM8  Swimming
#
#                                    Event  Medal  Total
# 0            Men's 100m Backstroke - S10    NaN      7
# 1             Men's 100m Butterfly - S10    NaN      7
# 2             Men's 100m Freestyle - S10    NaN      7
# 3    Men's 200m Individual Medley - SM10    NaN      7
# 4             Men's 400m Freestyle - S10    NaN      7
# ..                                   ...    ...    ...
# 931    Women's Individual Recurve - Open    NaN      2
# 932          Men's 100m Backstroke - S11    NaN      2
# 933       Men's 100m Breaststroke - SB11    NaN      2
# 934        Men's 100m Breaststroke - SB8    NaN      2
# 935   Men's 200m Individual Medley - SM8    NaN      2
#
# [936 rows x 6 columns]

# %%
#Clean up the html code
remove_pattern_1 = r'Sport Class:[^>]+>[^>]+>'
remove_pattern_2 = r'<span class="d-md-none">[^>]+</span>'
remove_pattern = r'|'.join((remove_pattern_1, remove_pattern_2))
mmedallists_html_clean_1 = re.sub(remove_pattern, '', mmedallists_html_full.decode("utf-8"))

#Switch country abbreviations with country names 
switch_pattern = re.compile(r'<abbr class="noc" title=("[^"]+")>([^<]+)</abbr>')
mmedallists_html_clean_2 = switch_pattern.sub(r'<abbr class="noc" title=\2>\1</abbr>', mmedallists_html_clean_1)

#Replace pictures of medals with medal names
replace_pattern_gold = r'<img class="medal-icon"\s[^\s]+\salt="Gold Medal">'
replace_pattern_silver = r'<img class="medal-icon"\s[^\s]+\salt="Silver Medal">'
replace_pattern_bronze = r'<img class="medal-icon"\s[^\s]+\salt="Bronze Medal">'

mmedallists_html_clean_3 = re.sub(replace_pattern_gold, 'Gold', mmedallists_html_clean_2)
mmedallists_html_clean_4 = re.sub(replace_pattern_silver, 'Silver', mmedallists_html_clean_3)
mmedallists_html_clean = re.sub(replace_pattern_bronze, 'Bronze', mmedallists_html_clean_4)

#Check out modified data
mmedallists_clean = pd.read_html(mmedallists_html_clean)
mmedallists = mmedallists_clean[0]

mmedallists.head(10)
# Out:
#    Rank                    Name     Sport  \
# 0     1  "Ukraine"KRYPAK Maksym  Swimming
# 1     1  "Ukraine"KRYPAK Maksym  Swimming
# 2     1  "Ukraine"KRYPAK Maksym  Swimming
# 3     1  "Ukraine"KRYPAK Maksym  Swimming
# 4     1  "Ukraine"KRYPAK Maksym  Swimming
# 5     1  "Ukraine"KRYPAK Maksym  Swimming
# 6     1  "Ukraine"KRYPAK Maksym  Swimming
# 7     2      "Belarus"BOKI Ihar  Swimming
# 8     2      "Belarus"BOKI Ihar  Swimming
# 9     2      "Belarus"BOKI Ihar  Swimming
#
#                                       Event   Medal  Total
# 0               Men's 100m Backstroke - S10    Gold      7
# 1                Men's 100m Butterfly - S10    Gold      7
# 2                Men's 100m Freestyle - S10    Gold      7
# 3       Men's 200m Individual Medley - SM10    Gold      7
# 4                Men's 400m Freestyle - S10    Gold      7
# 5                 Men's 50m Freestyle - S10  Silver      7
# 6  Men's 4x100m Freestyle Relay - 34 Points  Bronze      7
# 7               Men's 100m Backstroke - S13    Gold      5
# 8                Men's 100m Butterfly - S13    Gold      5
# 9       Men's 200m Individual Medley - SM13    Gold      5

# %%
#Group raws with identical information 
idet_cols = ['Rank', 'Name', 'Sport', 'Total']
mmedallists['Event'] = mmedallists.groupby(idet_cols)['Event'].transform(lambda x: '; '.join(x))
mmedallists['Medal'] = mmedallists.groupby(idet_cols)['Medal'].transform(lambda x: '; '.join(x))
mmedallists.drop_duplicates(inplace=True, ignore_index=True)
mmedallists
# Out:
#      Rank                                        Name       Sport  \
# 0       1                      "Ukraine"KRYPAK Maksym    Swimming
# 1       2                          "Belarus"BOKI Ihar    Swimming
# 2       3                     "Switzerland"HUG Marcel   Athletics
# 3       3         "People's Republic of China"LU Dong    Swimming
# 4       3       "People's Republic of China"ZHENG Tao    Swimming
# ..    ...                                         ...         ...
# 376   350                  "Japan"UEYONABARU Hirokazu   Athletics
# 377   350               "Great Britain"WILSON Georgia  Equestrian
# 378   350      "People's Republic of China"WU Chunyan     Archery
# 379   350      "People's Republic of China"YANG Bozun    Swimming
# 380   350  "People's Republic of China"YANG Guanglong    Swimming
#
#                                                  Event  \
# 0    Men's 100m Backstroke - S10; Men's 100m Butter...
# 1    Men's 100m Backstroke - S13; Men's 100m Butter...
# 2    Men's 1500m - T54; Men's 5000m - T54; Men's 80...
# 3    Mixed 4x50m Freestyle Relay - 20 Points; Women...
# 4    Men's 50m Backstroke - S5; Men's 50m Butterfly...
# ..                                                 ...
# 376                Men's 1500m - T52; Men's 400m - T52
# 377  Individual Freestyle Test - Grade II; Individu...
# 378  Mixed Team Recurve - Open; Women's Individual ...
# 379  Men's 100m Backstroke - S11; Men's 100m Breast...
# 380  Men's 100m Breaststroke - SB8; Men's 200m Indi...
#
#                                             Medal  Total
# 0    Gold; Gold; Gold; Gold; Gold; Silver; Bronze      7
# 1                    Gold; Gold; Gold; Gold; Gold      5
# 2                          Gold; Gold; Gold; Gold      4
# 3                          Gold; Gold; Gold; Gold      4
# 4                          Gold; Gold; Gold; Gold      4
# ..                                            ...    ...
# 376                                Bronze; Bronze      2
# 377                                Bronze; Bronze      2
# 378                                Bronze; Bronze      2
# 379                                Bronze; Bronze      2
# 380                                Bronze; Bronze      2
#
# [381 rows x 6 columns]

# %%
#Count Gold, Silver, and Bronze
mmedallists = mmedallists.assign(Gold = mmedallists['Medal'].str.count('Gold'))
mmedallists = mmedallists.assign(Silver = mmedallists['Medal'].str.count('Silver'))
mmedallists = mmedallists.assign(Bronze = mmedallists['Medal'].str.count('Bronze'))
mmedallists
# Out:
#      Rank                                        Name       Sport  \
# 0       1                      "Ukraine"KRYPAK Maksym    Swimming
# 1       2                          "Belarus"BOKI Ihar    Swimming
# 2       3                     "Switzerland"HUG Marcel   Athletics
# 3       3         "People's Republic of China"LU Dong    Swimming
# 4       3       "People's Republic of China"ZHENG Tao    Swimming
# ..    ...                                         ...         ...
# 376   350                  "Japan"UEYONABARU Hirokazu   Athletics
# 377   350               "Great Britain"WILSON Georgia  Equestrian
# 378   350      "People's Republic of China"WU Chunyan     Archery
# 379   350      "People's Republic of China"YANG Bozun    Swimming
# 380   350  "People's Republic of China"YANG Guanglong    Swimming
#
#                                                  Event  \
# 0    Men's 100m Backstroke - S10; Men's 100m Butter...
# 1    Men's 100m Backstroke - S13; Men's 100m Butter...
# 2    Men's 1500m - T54; Men's 5000m - T54; Men's 80...
# 3    Mixed 4x50m Freestyle Relay - 20 Points; Women...
# 4    Men's 50m Backstroke - S5; Men's 50m Butterfly...
# ..                                                 ...
# 376                Men's 1500m - T52; Men's 400m - T52
# 377  Individual Freestyle Test - Grade II; Individu...
# 378  Mixed Team Recurve - Open; Women's Individual ...
# 379  Men's 100m Backstroke - S11; Men's 100m Breast...
# 380  Men's 100m Breaststroke - SB8; Men's 200m Indi...
#
#                                             Medal  Total  Gold  Silver  Bronze
# 0    Gold; Gold; Gold; Gold; Gold; Silver; Bronze      7     5       1       1
# 1                    Gold; Gold; Gold; Gold; Gold      5     5       0       0
# 2                          Gold; Gold; Gold; Gold      4     4       0       0
# 3                          Gold; Gold; Gold; Gold      4     4       0       0
# 4                          Gold; Gold; Gold; Gold      4     4       0       0
# ..                                            ...    ...   ...     ...     ...
# 376                                Bronze; Bronze      2     0       0       2
# 377                                Bronze; Bronze      2     0       0       2
# 378                                Bronze; Bronze      2     0       0       2
# 379                                Bronze; Bronze      2     0       0       2
# 380                                Bronze; Bronze      2     0       0       2
#
# [381 rows x 9 columns]

# %%
#Remove redundant columns
mmedallists.drop(columns=['Event', 'Medal'], inplace=True)
mmedallists = mmedallists.reindex(columns=['Rank', 'Name', 'Sport', 'Gold', 'Silver', 'Bronze', 'Total'])
mmedallists
# Out:
#      Rank                                        Name       Sport  Gold  \
# 0       1                      "Ukraine"KRYPAK Maksym    Swimming     5
# 1       2                          "Belarus"BOKI Ihar    Swimming     5
# 2       3                     "Switzerland"HUG Marcel   Athletics     4
# 3       3         "People's Republic of China"LU Dong    Swimming     4
# 4       3       "People's Republic of China"ZHENG Tao    Swimming     4
# ..    ...                                         ...         ...   ...
# 376   350                  "Japan"UEYONABARU Hirokazu   Athletics     0
# 377   350               "Great Britain"WILSON Georgia  Equestrian     0
# 378   350      "People's Republic of China"WU Chunyan     Archery     0
# 379   350      "People's Republic of China"YANG Bozun    Swimming     0
# 380   350  "People's Republic of China"YANG Guanglong    Swimming     0
#
#      Silver  Bronze  Total
# 0         1       1      7
# 1         0       0      5
# 2         0       0      4
# 3         0       0      4
# 4         0       0      4
# ..      ...     ...    ...
# 376       0       2      2
# 377       0       2      2
# 378       0       2      2
# 379       0       2      2
# 380       0       2      2
#
# [381 rows x 7 columns]

# %%
#Create a separate column with country's name
mmedallists = mmedallists.assign(Team = mmedallists['Name'].str.extract('"([^"]+)"'))
mmedallists
# Out:
#      Rank                                        Name       Sport  Gold  \
# 0       1                      "Ukraine"KRYPAK Maksym    Swimming     5
# 1       2                          "Belarus"BOKI Ihar    Swimming     5
# 2       3                     "Switzerland"HUG Marcel   Athletics     4
# 3       3         "People's Republic of China"LU Dong    Swimming     4
# 4       3       "People's Republic of China"ZHENG Tao    Swimming     4
# ..    ...                                         ...         ...   ...
# 376   350                  "Japan"UEYONABARU Hirokazu   Athletics     0
# 377   350               "Great Britain"WILSON Georgia  Equestrian     0
# 378   350      "People's Republic of China"WU Chunyan     Archery     0
# 379   350      "People's Republic of China"YANG Bozun    Swimming     0
# 380   350  "People's Republic of China"YANG Guanglong    Swimming     0
#
#      Silver  Bronze  Total                        Team
# 0         1       1      7                     Ukraine
# 1         0       0      5                     Belarus
# 2         0       0      4                 Switzerland
# 3         0       0      4  People's Republic of China
# 4         0       0      4  People's Republic of China
# ..      ...     ...    ...                         ...
# 376       0       2      2                       Japan
# 377       0       2      2               Great Britain
# 378       0       2      2  People's Republic of China
# 379       0       2      2  People's Republic of China
# 380       0       2      2  People's Republic of China
#
# [381 rows x 8 columns]

# %%
#Remove country's name from the 'Name' column
mmedallists.Name = mmedallists.Name.str.replace(r'"([^"]+)"',r'',regex=True)
#rearange the columns
mmedallists = mmedallists.reindex(columns=['Rank', 'Name', 'Team', 'Sport', 'Gold', 'Silver', 'Bronze', 'Total'])
mmedallists
# Out:
#      Rank                 Name                        Team       Sport  Gold  \
# 0       1        KRYPAK Maksym                     Ukraine    Swimming     5
# 1       2            BOKI Ihar                     Belarus    Swimming     5
# 2       3           HUG Marcel                 Switzerland   Athletics     4
# 3       3              LU Dong  People's Republic of China    Swimming     4
# 4       3            ZHENG Tao  People's Republic of China    Swimming     4
# ..    ...                  ...                         ...         ...   ...
# 376   350  UEYONABARU Hirokazu                       Japan   Athletics     0
# 377   350       WILSON Georgia               Great Britain  Equestrian     0
# 378   350           WU Chunyan  People's Republic of China     Archery     0
# 379   350           YANG Bozun  People's Republic of China    Swimming     0
# 380   350       YANG Guanglong  People's Republic of China    Swimming     0
#
#      Silver  Bronze  Total
# 0         1       1      7
# 1         0       0      5
# 2         0       0      4
# 3         0       0      4
# 4         0       0      4
# ..      ...     ...    ...
# 376       0       2      2
# 377       0       2      2
# 378       0       2      2
# 379       0       2      2
# 380       0       2      2
#
# [381 rows x 8 columns]

# %%
#Export data to a cvs file
mmedallists.to_csv('MultiMedallists.csv', index=False)

# %%
#Script to look for matches
remove_pattern = re.compile(r'<span class="d-md-none">[^>]+</span>')
mmedallists_html_clean = re.sub(remove_pattern, '', mmedallists_html_full.decode("utf-8"))

matches = remove_pattern.finditer(mmedallists_html_full.decode("utf-8"))

for match in matches:
    print(match)
# Out:
# <re.Match object; span=(143220, 143259), match='<span class="d-md-none">KRYPAK M</span>'>
# <re.Match object; span=(146173, 146210), match='<span class="d-md-none">BOKI I</span>'>
# <re.Match object; span=(148661, 148697), match='<span class="d-md-none">HUG M</span>'>
# <re.Match object; span=(150873, 150908), match='<span class="d-md-none">LU D</span>'>
# <re.Match object; span=(153146, 153184), match='<span class="d-md-none">ZHENG T</span>'>
# <re.Match object; span=(155410, 155447), match='<span class="d-md-none">LONG J</span>'>
# <re.Match object; span=(158162, 158199), match='<span class="d-md-none">DUNN R</span>'>
# <re.Match object; span=(160676, 160724), match='<span class="d-md-none">GOMES SANTIAGO MC</span>'>
# <re.Match object; span=(163207, 163246), match='<span class="d-md-none">MARTIN W</span>'>
# <re.Match object; span=(165495, 165535), match='<span class="d-md-none">MAYHUGH N</span>'>
# <re.Match object; span=(167689, 167731), match='<span class="d-md-none">SHABALINA V</span>'>
# <re.Match object; span=(169951, 169991), match='<span class="d-md-none">ZHDANOV R</span>'>
# <re.Match object; span=(172450, 172490), match='<span class="d-md-none">DORSMAN R</span>'>
# <re.Match object; span=(174480, 174525), match='<span class="d-md-none">DURAND ELIAS O</span>'>
# <re.Match object; span=(176451, 176490), match='<span class="d-md-none">KALINA A</span>'>
# <re.Match object; span=(178484, 178522), match='<span class="d-md-none">PAEYO P</span>'>
# <re.Match object; span=(180468, 180508), match='<span class="d-md-none">PEARSON L</span>'>
# <re.Match object; span=(182473, 182511), match='<span class="d-md-none">SALEI R</span>'>
# <re.Match object; span=(184504, 184540), match='<span class="d-md-none">TAN S</span>'>
# <re.Match object; span=(186562, 186598), match='<span class="d-md-none">WEN X</span>'>
# <re.Match object; span=(188534, 188573), match='<span class="d-md-none">TRUSOV A</span>'>
# <re.Match object; span=(191280, 191319), match='<span class="d-md-none">SCHAER M</span>'>
# <re.Match object; span=(193711, 193749), match='<span class="d-md-none">GILLI C</span>'>
# <re.Match object; span=(196227, 196268), match='<span class="d-md-none">MERESHKO Y</span>'>
# <re.Match object; span=(198723, 198761), match='<span class="d-md-none">TERZI G</span>'>
# <re.Match object; span=(201238, 201281), match='<span class="d-md-none">ZIJDERVELD C</span>'>
# <re.Match object; span=(203771, 203809), match='<span class="d-md-none">FIRTH B</span>'>
# <re.Match object; span=(206026, 206064), match='<span class="d-md-none">TRIMI A</span>'>
# <re.Match object; span=(208274, 208313), match='<span class="d-md-none">RIVARD A</span>'>
# <re.Match object; span=(210807, 210843), match='<span class="d-md-none">JIA H</span>'>
# <re.Match object; span=(213099, 213137), match='<span class="d-md-none">JIANG Y</span>'>
# <re.Match object; span=(215340, 215379), match='<span class="d-md-none">PASCOE S</span>'>
# <re.Match object; span=(217640, 217677), match='<span class="d-md-none">RONG J</span>'>
# <re.Match object; span=(219898, 219940), match='<span class="d-md-none">BOCCIARDO F</span>'>
# <re.Match object; span=(221927, 221968), match='<span class="d-md-none">CROTHERS R</span>'>
# <re.Match object; span=(223939, 223979), match='<span class="d-md-none">DADAON AO</span>'>
# <re.Match object; span=(225985, 226033), match='<span class="d-md-none">dos SANTOS ARAUJO</span>'>
# <re.Match object; span=(228022, 228071), match='<span class="d-md-none">LEANI RATRI Oktila</span>>
# <re.Match object; span=(230053, 230089), match='<span class="d-md-none">LIU C</span>'>
# <re.Match object; span=(232044, 232079), match='<span class="d-md-none">MA J</span>'>
# <re.Match object; span=(234058, 234099), match='<span class="d-md-none">NIKOLAEV A</span>'>
# <re.Match object; span=(236064, 236103), match='<span class="d-md-none">POPHAM B</span>'>
# <re.Match object; span=(238114, 238150), match='<span class="d-md-none">SUN G</span>'>
# <re.Match object; span=(240148, 240194), match='<span class="d-md-none">VERA ANDRADE LM</span>'>
# <re.Match object; span=(242153, 242191), match='<span class="d-md-none">VOETS S</span>'>
# <re.Match object; span=(244201, 244243), match='<span class="d-md-none">WEGGEMANN M</span>'>
# <re.Match object; span=(246255, 246293), match='<span class="d-md-none">ZHANG L</span>'>
# <re.Match object; span=(248303, 248340), match='<span class="d-md-none">BIAN J</span>'>
# <re.Match object; span=(250347, 250390), match='<span class="d-md-none">de ROZARIO M</span>'>
# <re.Match object; span=(252328, 252367), match='<span class="d-md-none">MALYAR M</span>'>
# <re.Match object; span=(254382, 254423), match='<span class="d-md-none">TRUNNELL R</span>'>
# <re.Match object; span=(256419, 256467), match='<span class="d-md-none">van GANSEWINKEL M</span>'>
# <re.Match object; span=(258440, 258481), match='<span class="d-md-none">van GASS J</span>'>
# <re.Match object; span=(260496, 260533), match='<span class="d-md-none">ZHOU Z</span>'>
# <re.Match object; span=(262476, 262518), match='<span class="d-md-none">ANDREJCIK S</span>'>
# <re.Match object; span=(264251, 264290), match='<span class="d-md-none">ASPDEN H</span>'>
# <re.Match object; span=(266078, 266115), match='<span class="d-md-none">CHEN J</span>'>
# <re.Match object; span=(267863, 267900), match='<span class="d-md-none">CHEN M</span>'>
# <re.Match object; span=(269622, 269663), match='<span class="d-md-none">COCKROFT H</span>'>
# <re.Match object; span=(271392, 271428), match='<span class="d-md-none">COX K</span>'>
# <re.Match object; span=(273186, 273227), match='<span class="d-md-none">de GROOT D</span>'>
# <re.Match object; span=(274970, 275011), match='<span class="d-md-none">DUNLEVY KG</span>'>
# <re.Match object; span=(276772, 276809), match='<span class="d-md-none">FENG P</span>'>
# <re.Match object; span=(278568, 278605), match='<span class="d-md-none">FENG Y</span>'>
# <re.Match object; span=(280370, 280409), match='<span class="d-md-none">GEORGE M</span>'>
# <re.Match object; span=(282187, 282228), match='<span class="d-md-none">GRISWOLD R</span>'>
# <re.Match object; span=(283994, 284029), match='<span class="d-md-none">GU H</span>'>
# <re.Match object; span=(285798, 285833), match='<span class="d-md-none">HE Z</span>'>
# <re.Match object; span=(287552, 287592), match='<span class="d-md-none">JACQUES Y</span>'>
# <re.Match object; span=(289344, 289384), match='<span class="d-md-none">JENKINS M</span>'>
# <re.Match object; span=(291166, 291209), match='<span class="d-md-none">JORGENSEN TT</span>'>
# <re.Match object; span=(292959, 292997), match='<span class="d-md-none">KTILA W</span>'>
# <re.Match object; span=(294707, 294748), match='<span class="d-md-none">KUZYUKOV A</span>'>
# <re.Match object; span=(296504, 296546), match='<span class="d-md-none">LAMIRAULT F</span>'>
# <re.Match object; span=(298305, 298340), match='<span class="d-md-none">LI H</span>'>
# <re.Match object; span=(300108, 300144), match='<span class="d-md-none">LIU J</span>'>
# <re.Match object; span=(301894, 301930), match='<span class="d-md-none">LIU L</span>'>
# <re.Match object; span=(303659, 303695), match='<span class="d-md-none">LIU Y</span>'>
# <re.Match object; span=(305446, 305487), match='<span class="d-md-none">MAHLANGU N</span>'>
# <re.Match object; span=(307200, 307240), match='<span class="d-md-none">MAJUNKE J</span>'>
# <re.Match object; span=(309001, 309037), match='<span class="d-md-none">MAO J</span>'>
# <re.Match object; span=(310810, 310850), match='<span class="d-md-none">MASTERS O</span>'>
# <re.Match object; span=(312585, 312625), match='<span class="d-md-none">McGRATH C</span>'>
# <re.Match object; span=(314364, 314405), match='<span class="d-md-none">MOZGOVOI B</span>'>
# <re.Match object; span=(316147, 316184), match='<span class="d-md-none">PLAT J</span>'>
# <re.Match object; span=(317922, 317957), match='<span class="d-md-none">QU Z</span>'>
# <re.Match object; span=(319653, 319692), match='<span class="d-md-none">RISTIC D</span>'>
# <re.Match object; span=(321420, 321461), match='<span class="d-md-none">SAFRONOV D</span>'>
# <re.Match object; span=(323159, 323196), match='<span class="d-md-none">SATO T</span>'>
# <re.Match object; span=(324894, 324933), match='<span class="d-md-none">SATOMI S</span>'>
# <re.Match object; span=(326637, 326677), match='<span class="d-md-none">SHALABI I</span>'>
# <re.Match object; span=(328433, 328469), match='<span class="d-md-none">SHI Y</span>'>
# <re.Match object; span=(330218, 330259), match='<span class="d-md-none">STICKNEY M</span>'>
# <re.Match object; span=(332014, 332053), match='<span class="d-md-none">STOREY S</span>'>
# <re.Match object; span=(333772, 333812), match='<span class="d-md-none">SUGIURA K</span>'>
# <re.Match object; span=(335570, 335617), match='<span class="d-md-none">SUMMERS-NEWTON M</span>'>
# <re.Match object; span=(337372, 337410), match='<span class="d-md-none">TLILI R</span>'>
# <re.Match object; span=(339142, 339181), match='<span class="d-md-none">VALIZE M</span>'>
# <re.Match object; span=(340922, 340961), match='<span class="d-md-none">WATSON B</span>'>
# <re.Match object; span=(342711, 342747), match='<span class="d-md-none">XUE J</span>'>
# <re.Match object; span=(344500, 344536), match='<span class="d-md-none">YAN S</span>'>
# <re.Match object; span=(346257, 346294), match='<span class="d-md-none">YIP PX</span>'>
# <re.Match object; span=(348048, 348086), match='<span class="d-md-none">ZHANG B</span>'>
# <re.Match object; span=(349845, 349882), match='<span class="d-md-none">ZHAO S</span>'>
# <re.Match object; span=(351626, 351663), match='<span class="d-md-none">ZHOU X</span>'>
# <re.Match object; span=(353398, 353435), match='<span class="d-md-none">ZHOU Y</span>'>
# <re.Match object; span=(355190, 355226), match='<span class="d-md-none">ZOU L</span>'>
# <re.Match object; span=(356945, 356986), match='<span class="d-md-none">RAIMONDI S</span>'>
# <re.Match object; span=(359940, 359979), match='<span class="d-md-none">FANTIN A</span>'>
# <re.Match object; span=(362441, 362480), match='<span class="d-md-none">SUZUKI T</span>'>
# <re.Match object; span=(364963, 365000), match='<span class="d-md-none">WANG L</span>'>
# <re.Match object; span=(367435, 367476), match='<span class="d-md-none">BANDEIRA G</span>'>
# <re.Match object; span=(369706, 369746), match='<span class="d-md-none">BARLAAM S</span>'>
# <re.Match object; span=(371978, 372024), match='<span class="d-md-none">CRISPIN CORZO N</span>'>
# <re.Match object; span=(374237, 374278), match='<span class="d-md-none">PIKALOVA D</span>'>
# <re.Match object; span=(376500, 376539), match='<span class="d-md-none">ABARZA A</span>'>
# <re.Match object; span=(378515, 378553), match='<span class="d-md-none">BAKER N</span>'>
# <re.Match object; span=(380566, 380601), match='<span class="d-md-none">HU D</span>'>
# <re.Match object; span=(382574, 382618), match='<span class="d-md-none">ISHCHIULOVA V</span>'>
# <re.Match object; span=(384615, 384655), match='<span class="d-md-none">KONKOLY Z</span>'>
# <re.Match object; span=(386670, 386709), match='<span class="d-md-none">MALONE N</span>'>
# <re.Match object; span=(388688, 388727), match='<span class="d-md-none">MARTIN R</span>'>
# <re.Match object; span=(390702, 390740), match='<span class="d-md-none">MASON B</span>'>
# <re.Match object; span=(392678, 392718), match='<span class="d-md-none">MAZZONE L</span>'>
# <re.Match object; span=(394662, 394698), match='<span class="d-md-none">PAP B</span>'>
# <re.Match object; span=(396677, 396716), match='<span class="d-md-none">VDOVIN A</span>'>
# <re.Match object; span=(398680, 398717), match='<span class="d-md-none">ZHOU Y</span>'>
# <re.Match object; span=(400732, 400768), match='<span class="d-md-none">CAI L</span>'>
# <re.Match object; span=(403010, 403051), match='<span class="d-md-none">PALAZZO XF</span>'>
# <re.Match object; span=(405318, 405366), match='<span class="d-md-none">SERRANO ZARATE CD</span>'>
# <re.Match object; span=(407617, 407665), match='<span class="d-md-none">BELARMINO PEREIRA</span>'>
# <re.Match object; span=(409673, 409721), match='<span class="d-md-none">FERNANDEZ INFANTE</span>'>
# <re.Match object; span=(411738, 411779), match='<span class="d-md-none">GILLIVER P</span>'>
# <re.Match object; span=(413771, 413810), match='<span class="d-md-none">HANCE BJ</span>'>
# <re.Match object; span=(415820, 415858), match='<span class="d-md-none">JIANG F</span>'>
# <re.Match object; span=(417800, 417840), match='<span class="d-md-none">JOUANNY F</span>'>
# <re.Match object; span=(419821, 419856), match='<span class="d-md-none">LI G</span>'>
# <re.Match object; span=(421852, 421887), match='<span class="d-md-none">LI Z</span>'>
# <re.Match object; span=(423868, 423911), match='<span class="d-md-none">LOPEZ DIAZ D</span>'>
# <re.Match object; span=(425919, 425957), match='<span class="d-md-none">MARKS E</span>'>
# <re.Match object; span=(427973, 428014), match='<span class="d-md-none">McFADDEN T</span>'>
# <re.Match object; span=(429968, 430012), match='<span class="d-md-none">OSTAPCHENKO D</span>'>
# <re.Match object; span=(431999, 432036), match='<span class="d-md-none">YUAN W</span>'>
# <re.Match object; span=(434012, 434051), match='<span class="d-md-none">ALCOTT D</span>'>
# <re.Match object; span=(435790, 435831), match='<span class="d-md-none">ATHMANI SD</span>'>
# <re.Match object; span=(437585, 437621), match='<span class="d-md-none">CAO N</span>'>
# <re.Match object; span=(439380, 439418), match='<span class="d-md-none">CHENG H</span>'>
# <re.Match object; span=(441174, 441211), match='<span class="d-md-none">COAN M</span>'>
# <re.Match object; span=(442952, 442990), match='<span class="d-md-none">CUNDY J</span>'>
# <re.Match object; span=(444752, 444794), match='<span class="d-md-none">da SILVA AR</span>'>
# <re.Match object; span=(446528, 446567), match='<span class="d-md-none">DORRIS D</span>'>
# <re.Match object; span=(448329, 448373), match='<span class="d-md-none">DRAHONINSKY D</span>'>
# <re.Match object; span=(450077, 450115), match='<span class="d-md-none">GENYN P</span>'>
# <re.Match object; span=(451816, 451855), match='<span class="d-md-none">GONTAR A</span>'>
# <re.Match object; span=(453591, 453633), match='<span class="d-md-none">GRANICHKA A</span>'>
# <re.Match object; span=(455421, 455466), match='<span class="d-md-none">GUITY GUITY SI</span>'>
# <re.Match object; span=(457192, 457232), match='<span class="d-md-none">HILTROP N</span>'>
# <re.Match object; span=(459019, 459057), match='<span class="d-md-none">HUANG W</span>'>
# <re.Match object; span=(460818, 460856), match='<span class="d-md-none">HUANG X</span>'>
# <re.Match object; span=(462602, 462650), match='<span class="d-md-none">IGLESIAS FORNEIRO</span>'>
# <re.Match object; span=(464393, 464433), match='<span class="d-md-none">KEARNEY T</span>'>
# <re.Match object; span=(466153, 466192), match='<span class="d-md-none">KIMURA K</span>'>
# <re.Match object; span=(467943, 467986), match='<span class="d-md-none">KOZAKOWSKA R</span>'>
# <re.Match object; span=(469699, 469741), match='<span class="d-md-none">KRIVSHINA A</span>'>
# <re.Match object; span=(471489, 471528), match='<span class="d-md-none">LEAUTE A</span>'>
# <re.Match object; span=(473278, 473315), match='<span class="d-md-none">LEI LN</span>'>
# <re.Match object; span=(475074, 475110), match='<span class="d-md-none">LIU Y</span>'>
# <re.Match object; span=(476813, 476851), match='<span class="d-md-none">MAZUR L</span>'>
# <re.Match object; span=(478583, 478618), match='<span class="d-md-none">MI N</span>'>
# <re.Match object; span=(480350, 480393), match='<span class="d-md-none">MOSKALENKO A</span>'>
# <re.Match object; span=(482163, 482200), match='<span class="d-md-none">OLAD M</span>'>
# <re.Match object; span=(483930, 483973), match='<span class="d-md-none">PAENG-NUEA A</span>'>
# <re.Match object; span=(485688, 485730), match='<span class="d-md-none">PIISPANEN T</span>'>
# <re.Match object; span=(487457, 487498), match='<span class="d-md-none">SCHRODER S</span>'>
# <re.Match object; span=(489222, 489261), match='<span class="d-md-none">SERBIN M</span>'>
# <re.Match object; span=(491007, 491048), match='<span class="d-md-none">SHABUROV M</span>'>
# <re.Match object; span=(492795, 492834), match='<span class="d-md-none">STRENG F</span>'>
# <re.Match object; span=(494528, 494568), match='<span class="d-md-none">TARASOV D</span>'>
# <re.Match object; span=(496325, 496368), match='<span class="d-md-none">ter SCHURE V</span>'>
# <re.Match object; span=(498137, 498178), match='<span class="d-md-none">TOWNSEND R</span>'>
# <re.Match object; span=(499904, 499943), match='<span class="d-md-none">TURNER J</span>'>
# <re.Match object; span=(501663, 501704), match='<span class="d-md-none">VALIYEVA L</span>'>
# <re.Match object; span=(503433, 503473), match='<span class="d-md-none">van ZON K</span>'>
# <re.Match object; span=(505218, 505255), match='<span class="d-md-none">VIO BM</span>'>
# <re.Match object; span=(507024, 507063), match='<span class="d-md-none">VONGSA W</span>'>
# <re.Match object; span=(508783, 508821), match='<span class="d-md-none">WELLS S</span>'>
# <re.Match object; span=(510555, 510593), match='<span class="d-md-none">WIGGS E</span>'>
# <re.Match object; span=(512345, 512382), match='<span class="d-md-none">YANG Q</span>'>
# <re.Match object; span=(514115, 514153), match='<span class="d-md-none">ZEYEN A</span>'>
# <re.Match object; span=(515915, 515953), match='<span class="d-md-none">ZHANG C</span>'>
# <re.Match object; span=(517748, 517785), match='<span class="d-md-none">ZHOU J</span>'>
# <re.Match object; span=(519567, 519603), match='<span class="d-md-none">ZHU D</span>'>
# <re.Match object; span=(521346, 521382), match='<span class="d-md-none">ZOU L</span>'>
# <re.Match object; span=(523144, 523187), match='<span class="d-md-none">APPLEGATE JJ</span>'>
# <re.Match object; span=(525176, 525215), match='<span class="d-md-none">DUBROV D</span>'>
# <re.Match object; span=(527217, 527256), match='<span class="d-md-none">GLOCK TH</span>'>
# <re.Match object; span=(529263, 529312), match='<span class="d-md-none">HERNANDEZ HERNAND.</span>>
# <re.Match object; span=(531314, 531355), match='<span class="d-md-none">ABLINGER W</span>'>
# <re.Match object; span=(533106, 533152), match='<span class="d-md-none">ABRAHAM GEBRU D</span>'>
# <re.Match object; span=(534916, 534955), match='<span class="d-md-none">AUSTIN E</span>'>
# <re.Match object; span=(536673, 536709), match='<span class="d-md-none">AVE L</span>'>
# <re.Match object; span=(538426, 538468), match='<span class="d-md-none">BOHODAIKO Y</span>'>
# <re.Match object; span=(540229, 540276), match='<span class="d-md-none">CABELLO LLAMAS A</span>'>
# <re.Match object; span=(542049, 542091), match='<span class="d-md-none">DEBRUNNER C</span>'>
# <re.Match object; span=(543841, 543876), match='<span class="d-md-none">DI D</span>'>
# <re.Match object; span=(545614, 545663), match='<span class="d-md-none">FERREIRA dos SANT.</span>>
# <re.Match object; span=(547390, 547429), match='<span class="d-md-none">FLOORS J</span>'>
# <re.Match object; span=(549150, 549196), match='<span class="d-md-none">GARROTE MUNOZ S</span>'>
# <re.Match object; span=(550944, 550983), match='<span class="d-md-none">JANSEN J</span>'>
# <re.Match object; span=(552709, 552750), match='<span class="d-md-none">KAJIWARA D</span>'>
# <re.Match object; span=(554453, 554493), match='<span class="d-md-none">LEKHARA A</span>'>
# <re.Match object; span=(556270, 556315), match='<span class="d-md-none">LEMOS RIVAS JG</span>'>
# <re.Match object; span=(558060, 558097), match='<span class="d-md-none">LEVY M</span>'>
# <re.Match object; span=(559875, 559912), match='<span class="d-md-none">LIAO K</span>'>
# <re.Match object; span=(561646, 561687), match='<span class="d-md-none">LLOVERAS A</span>'>
# <re.Match object; span=(563415, 563455), match='<span class="d-md-none">METELKA J</span>'>
# <re.Match object; span=(565195, 565233), match='<span class="d-md-none">OVSII Z</span>'>
# <re.Match object; span=(567003, 567043), match='<span class="d-md-none">PAGONIS A</span>'>
# <re.Match object; span=(568799, 568839), match='<span class="d-md-none">PARTYKA N</span>'>
# <re.Match object; span=(570566, 570606), match='<span class="d-md-none">PAVLOVA M</span>'>
# <re.Match object; span=(572359, 572395), match='<span class="d-md-none">PEK K</span>'>
# <re.Match object; span=(574137, 574181), match='<span class="d-md-none">PELENDRITOU K</span>'>
# <re.Match object; span=(575965, 576002), match='<span class="d-md-none">PENG W</span>'>
# <re.Match object; span=(577770, 577812), match='<span class="d-md-none">ROMANCHUK D</span>'>
# <re.Match object; span=(579546, 579586), match='<span class="d-md-none">RUSSELL H</span>'>
# <re.Match object; span=(581363, 581403), match='<span class="d-md-none">SCARONI S</span>'>
# <re.Match object; span=(583116, 583157), match='<span class="d-md-none">SKALIUKH A</span>'>
# <re.Match object; span=(584890, 584931), match='<span class="d-md-none">SOTNIKOV V</span>'>
# <re.Match object; span=(586686, 586728), match='<span class="d-md-none">STETSENKO A</span>'>
# <re.Match object; span=(588479, 588520), match='<span class="d-md-none">SUGIMURA H</span>'>
# <re.Match object; span=(590235, 590272), match='<span class="d-md-none">VINK N</span>'>
# <re.Match object; span=(591985, 592026), match='<span class="d-md-none">YAMAZAKI Y</span>'>
# <re.Match object; span=(593764, 593800), match='<span class="d-md-none">YAO C</span>'>
# <re.Match object; span=(595577, 595614), match='<span class="d-md-none">ZHAI X</span>'>
# <re.Match object; span=(597368, 597406), match='<span class="d-md-none">ZHANG M</span>'>
# <re.Match object; span=(599132, 599172), match='<span class="d-md-none">LAKATOS B</span>'>
# <re.Match object; span=(601339, 601381), match='<span class="d-md-none">BOTURCHUK O</span>'>
# <re.Match object; span=(603325, 603366), match='<span class="d-md-none">VERGNAUD L</span>'>
# <re.Match object; span=(605313, 605354), match='<span class="d-md-none">BEGGIATO L</span>'>
# <re.Match object; span=(607333, 607374), match='<span class="d-md-none">CLIFFORD J</span>'>
# <re.Match object; span=(609321, 609359), match='<span class="d-md-none">HODGE T</span>'>
# <re.Match object; span=(611357, 611396), match='<span class="d-md-none">HOSMAR F</span>'>
# <re.Match object; span=(613350, 613389), match='<span class="d-md-none">TOMITA U</span>'>
# <re.Match object; span=(615406, 615443), match='<span class="d-md-none">ZHOU H</span>'>
# <re.Match object; span=(617403, 617444), match='<span class="d-md-none">ADENEGAN K</span>'>
# <re.Match object; span=(619181, 619220), match='<span class="d-md-none">BAYLEY W</span>'>
# <re.Match object; span=(620943, 620980), match='<span class="d-md-none">BECK A</span>'>
# <re.Match object; span=(622712, 622753), match='<span class="d-md-none">BENSUSAN I</span>'>
# <re.Match object; span=(624489, 624530), match='<span class="d-md-none">BRUINSMA L</span>'>
# <re.Match object; span=(626283, 626323), match='<span class="d-md-none">CAIRONI M</span>'>
# <re.Match object; span=(628051, 628093), match='<span class="d-md-none">DEMENTYEV Y</span>'>
# <re.Match object; span=(629822, 629861), match='<span class="d-md-none">DIDUKH V</span>'>
# <re.Match object; span=(631594, 631633), match='<span class="d-md-none">FEDOTA O</span>'>
# <re.Match object; span=(633398, 633441), match='<span class="d-md-none">FRUEHWIRTH T</span>'>
# <re.Match object; span=(635169, 635212), match='<span class="d-md-none">GONCHAROVA M</span>'>
# <re.Match object; span=(636936, 636973), match='<span class="d-md-none">HOLT I</span>'>
# <re.Match object; span=(638714, 638751), match='<span class="d-md-none">KIM HU</span>'>
# <re.Match object; span=(640508, 640546), match='<span class="d-md-none">KIM J J</span>'>
# <re.Match object; span=(642289, 642326), match='<span class="d-md-none">KIM YG</span>'>
# <re.Match object; span=(644045, 644081), match='<span class="d-md-none">KOL A</span>'>
# <re.Match object; span=(645834, 645878), match='<span class="d-md-none">LANE-WRIGHT C</span>'>
# <re.Match object; span=(647612, 647653), match='<span class="d-md-none">LEGNANTE A</span>'>
# <re.Match object; span=(649377, 649412), match='<span class="d-md-none">MA L</span>'>
# <re.Match object; span=(651155, 651196), match='<span class="d-md-none">MUSILOVA S</span>'>
# <re.Match object; span=(652912, 652958), match='<span class="d-md-none">PONCE BERTRAN A</span>'>
# <re.Match object; span=(654693, 654730), match='<span class="d-md-none">PUCH P</span>'>
# <re.Match object; span=(656511, 656551), match='<span class="d-md-none">ROBERTS J</span>'>
# <re.Match object; span=(658286, 658331), match='<span class="d-md-none">SCHMIDBERGER T</span>'>
# <re.Match object; span=(660092, 660129), match='<span class="d-md-none">SEO SY</span>'>
# <re.Match object; span=(661904, 661953), match='<span class="d-md-none">SIMPLICIO da SILVA</span>>
# <re.Match object; span=(663688, 663727), match='<span class="d-md-none">SNIKUS R</span>'>
# <re.Match object; span=(665504, 665540), match='<span class="d-md-none">SUN B</span>'>
# <re.Match object; span=(667267, 667308), match='<span class="d-md-none">TSVIETOV I</span>'>
# <re.Match object; span=(669011, 669050), match='<span class="d-md-none">YAMADA M</span>'>
# <re.Match object; span=(670807, 670846), match='<span class="d-md-none">COUTYA D</span>'>
# <re.Match object; span=(673071, 673110), match='<span class="d-md-none">KRUGER L</span>'>
# <re.Match object; span=(675361, 675399), match='<span class="d-md-none">CLEGG S</span>'>
# <re.Match object; span=(677407, 677444), match='<span class="d-md-none">TIAN J</span>'>
# <re.Match object; span=(679439, 679479), match='<span class="d-md-none">VERAKSA M</span>'>
# <re.Match object; span=(681477, 681519), match='<span class="d-md-none">AITCHISON D</span>'>
# <re.Match object; span=(683282, 683324), match='<span class="d-md-none">ALHAMMADI M</span>'>
# <re.Match object; span=(685029, 685068), match='<span class="d-md-none">ALIEVA M</span>'>
# <re.Match object; span=(686809, 686850), match='<span class="d-md-none">BEECROFT E</span>'>
# <re.Match object; span=(688605, 688645), match='<span class="d-md-none">BOYKOVA V</span>'>
# <re.Match object; span=(690415, 690453), match='<span class="d-md-none">BREUS Y</span>'>
# <re.Match object; span=(692203, 692243), match='<span class="d-md-none">BUTKOVA N</span>'>
# <re.Match object; span=(693996, 694034), match='<span class="d-md-none">CELEN T</span>'>
# <re.Match object; span=(695787, 695824), match='<span class="d-md-none">CHA SY</span>'>
# <re.Match object; span=(697582, 697620), match='<span class="d-md-none">CHENG J</span>'>
# <re.Match object; span=(699375, 699416), match='<span class="d-md-none">COCHRANE B</span>'>
# <re.Match object; span=(701179, 701219), match='<span class="d-md-none">COETZEE L</span>'>
# <re.Match object; span=(702940, 702977), match='<span class="d-md-none">COLE E</span>'>
# <re.Match object; span=(704741, 704789), match='<span class="d-md-none">COSTA ALEXANDRE B</span>'>
# <re.Match object; span=(706533, 706572), match='<span class="d-md-none">CZUPER R</span>'>
# <re.Match object; span=(708298, 708338), match='<span class="d-md-none">DADZITE D</span>'>
# <re.Match object; span=(710103, 710139), match='<span class="d-md-none">DAI Y</span>'>
# <re.Match object; span=(711838, 711877), match='<span class="d-md-none">DIDIER U</span>'>
# <re.Match object; span=(713635, 713681), match='<span class="d-md-none">DREOCK KAESER A</span>'>
# <re.Match object; span=(715438, 715479), match='<span class="d-md-none">EGBERINK T</span>'>
# <re.Match object; span=(717209, 717253), match='<span class="d-md-none">EMELIANTSEV V</span>'>
# <re.Match object; span=(719007, 719046), match='<span class="d-md-none">FIDDES L</span>'>
# <re.Match object; span=(720821, 720866), match='<span class="d-md-none">GARASHCHENKO K</span>'>
# <re.Match object; span=(722614, 722653), match='<span class="d-md-none">GASCON S</span>'>
# <re.Match object; span=(724428, 724464), match='<span class="d-md-none">HUA D</span>'>
# <re.Match object; span=(726199, 726239), match='<span class="d-md-none">JEBABLI R</span>'>
# <re.Match object; span=(727987, 728036), match='<span class="d-md-none">JIMENEZ SANCHEZ DF</span>>
# <re.Match object; span=(729763, 729802), match='<span class="d-md-none">KAMIJI Y</span>'>
# <re.Match object; span=(731554, 731597), match='<span class="d-md-none">KARABARDAK P</span>'>
# <re.Match object; span=(733355, 733396), match='<span class="d-md-none">KINGHORN S</span>'>
# <re.Match object; span=(735117, 735159), match='<span class="d-md-none">KOVALCHUK V</span>'>
# <re.Match object; span=(736917, 736959), match='<span class="d-md-none">KURBANOVA N</span>'>
# <re.Match object; span=(738725, 738768), match='<span class="d-md-none">LAM-WATSON O</span>'>
# <re.Match object; span=(740533, 740570), match='<span class="d-md-none">LEE DS</span>'>
# <re.Match object; span=(742308, 742345), match='<span class="d-md-none">LEE MG</span>'>
# <re.Match object; span=(744101, 744140), match='<span class="d-md-none">LEUNG YW</span>'>
# <re.Match object; span=(745865, 745900), match='<span class="d-md-none">LI Y</span>'>
# <re.Match object; span=(747650, 747685), match='<span class="d-md-none">MA H</span>'>
# <re.Match object; span=(749439, 749478), match='<span class="d-md-none">MADSEN C</span>'>
# <re.Match object; span=(751194, 751239), match='<span class="d-md-none">MARQUES SOTO N</span>'>
# <re.Match object; span=(753006, 753048), match='<span class="d-md-none">NIKOLENKO M</span>'>
# <re.Match object; span=(754812, 754850), match='<span class="d-md-none">PARK JC</span>'>
# <re.Match object; span=(756604, 756641), match='<span class="d-md-none">PARK J</span>'>
# <re.Match object; span=(758393, 758435), match='<span class="d-md-none">PATTERSON G</span>'>
# <re.Match object; span=(760208, 760248), match='<span class="d-md-none">PEACOCK J</span>'>
# <re.Match object; span=(761979, 762025), match='<span class="d-md-none">POLYCHRONIDIS G</span>'>
# <re.Match object; span=(763740, 763781), match='<span class="d-md-none">POOKKHAM S</span>'>
# <re.Match object; span=(765491, 765530), match='<span class="d-md-none">PORTAL A</span>'>
# <re.Match object; span=(767306, 767343), match='<span class="d-md-none">REID G</span>'>
# <re.Match object; span=(769068, 769109), match='<span class="d-md-none">SAFONOVA V</span>'>
# <re.Match object; span=(770848, 770889), match='<span class="d-md-none">SCHAEFER L</span>'>
# <re.Match object; span=(772587, 772626), match='<span class="d-md-none">SINGHRAJ</span>'>
# <re.Match object; span=(774366, 774406), match='<span class="d-md-none">STEDMAN W</span>'>
# <re.Match object; span=(776122, 776160), match='<span class="d-md-none">STORM R</span>'>
# <re.Match object; span=(777896, 777935), match='<span class="d-md-none">SUZUKI A</span>'>
# <re.Match object; span=(779659, 779698), match='<span class="d-md-none">TAKKEN B</span>'>
# <re.Match object; span=(781459, 781499), match='<span class="d-md-none">TIRSEK FG</span>'>
# <re.Match object; span=(783276, 783322), match='<span class="d-md-none">van der HORST R</span>'>
# <re.Match object; span=(785066, 785106), match='<span class="d-md-none">VINCENT I</span>'>
# <re.Match object; span=(786858, 786895), match='<span class="d-md-none">WADA S</span>'>
# <re.Match object; span=(788635, 788674), match='<span class="d-md-none">WHILEY J</span>'>
# <re.Match object; span=(790443, 790481), match='<span class="d-md-none">XIONG G</span>'>
# <re.Match object; span=(792245, 792281), match='<span class="d-md-none">YIN M</span>'>
# <re.Match object; span=(794018, 794055), match='<span class="d-md-none">YOON J</span>'>
# <re.Match object; span=(795824, 795862), match='<span class="d-md-none">YOUNG C</span>'>
# <re.Match object; span=(797654, 797691), match='<span class="d-md-none">ZHAO L</span>'>
# <re.Match object; span=(799411, 799452), match='<span class="d-md-none">BOGGIONI M</span>'>
# <re.Match object; span=(801439, 801481), match='<span class="d-md-none">DANILENKO V</span>'>
# <re.Match object; span=(803454, 803500), match='<span class="d-md-none">de FARIA DIAS D</span>'>
# <re.Match object; span=(805477, 805516), match='<span class="d-md-none">SCHOTT V</span>'>
# <re.Match object; span=(807509, 807550), match='<span class="d-md-none">BARNEOUD A</span>'>
# <re.Match object; span=(809287, 809328), match='<span class="d-md-none">BETTELLA F</span>'>
# <re.Match object; span=(811052, 811094), match='<span class="d-md-none">CHEBANIKA R</span>'>
# <re.Match object; span=(812829, 812868), match='<span class="d-md-none">CLAEYS M</span>'>
# <re.Match object; span=(814644, 814683), match='<span class="d-md-none">CROSBY K</span>'>
# <re.Match object; span=(816433, 816470), match='<span class="d-md-none">DANA A</span>'>
# <re.Match object; span=(818203, 818244), match='<span class="d-md-none">DEDEKIND K</span>'>
# <re.Match object; span=(820016, 820056), match='<span class="d-md-none">GAFFNEY J</span>'>
# <re.Match object; span=(821797, 821835), match='<span class="d-md-none">GRECO P</span>'>
# <re.Match object; span=(823574, 823614), match='<span class="d-md-none">GRITSCH A</span>'>
# <re.Match object; span=(825338, 825377), match='<span class="d-md-none">HABSCH R</span>'>
# <re.Match object; span=(827092, 827134), match='<span class="d-md-none">JANNERING L</span>'>
# <re.Match object; span=(828851, 828893), match='<span class="d-md-none">KALASHIAN A</span>'>
# <re.Match object; span=(830611, 830656), match='<span class="d-md-none">KAMKASOMPHOU T</span>'>
# <re.Match object; span=(832404, 832445), match='<span class="d-md-none">KHONGRAK P</span>'>
# <re.Match object; span=(834167, 834206), match='<span class="d-md-none">LEAUTE A</span>'>
# <re.Match object; span=(835945, 835982), match='<span class="d-md-none">LYLE M</span>'>
# <re.Match object; span=(837686, 837722), match='<span class="d-md-none">MAI I</span>'>
# <re.Match object; span=(839441, 839482), match='<span class="d-md-none">MORGANTI S</span>'>
# <re.Match object; span=(841224, 841266), match='<span class="d-md-none">SHCHETNIK I</span>'>
# <re.Match object; span=(843007, 843048), match='<span class="d-md-none">SHISHOVA I</span>'>
# <re.Match object; span=(844784, 844825), match='<span class="d-md-none">STEPHENS K</span>'>
# <re.Match object; span=(846581, 846620), match='<span class="d-md-none">SUGINO A</span>'>
# <re.Match object; span=(848325, 848363), match='<span class="d-md-none">TAPIA O</span>'>
# <re.Match object; span=(850123, 850172), match='<span class="d-md-none">TEIXEIRA de SOUZA.</span>>
# <re.Match object; span=(851933, 851977), match='<span class="d-md-none">THOMAS KANE T</span>'>
# <re.Match object; span=(853739, 853778), match='<span class="d-md-none">THOMAS M</span>'>
# <re.Match object; span=(855512, 855555), match='<span class="d-md-none">UEYONABARU H</span>'>
# <re.Match object; span=(857293, 857332), match='<span class="d-md-none">WILSON G</span>'>
# <re.Match object; span=(859104, 859139), match='<span class="d-md-none">WU C</span>'>
# <re.Match object; span=(860893, 860930), match='<span class="d-md-none">YANG B</span>'>
# <re.Match object; span=(862716, 862753), match='<span class="d-md-none">YANG G</span>'>
